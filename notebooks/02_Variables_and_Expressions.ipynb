# %%
x = 2 + 2
print(x)
print(5)
# Out:
# 4
# 5

# %%
x = 2 + 2
print(type(x))
print(type('123'))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = 2 + 2
print(id(x))
print(id('ABC'))
# Out:
# 105547961268232
# 105547960959200

# %%
my_list = [10,'bw']
print(my_list)
my_list.append('abc')
print('After append:',my_list)
my_list.pop(1)
print('After pop:',my_list)
my_list.remove('abc')
print('After remove:',my_list)
# Out:
# [10, 'bw']
# After append: [10, 'bw', 'abc']
# After pop: [10, 'abc']
# After remove: [10]
