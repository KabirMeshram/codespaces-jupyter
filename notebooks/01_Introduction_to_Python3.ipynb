# %%
print("Namaskar World")
# Out:
# Namaskar World

# %%
print("Hello there")
print("my name is......")
print("Karl?")
# Out:
# Hello there
# my name is......
# Karl?

# %%
print("Hello there", end=' ')
print("my name is......",end=' ')
print("Karl?",end=' ')
# Out:
# Hello there my name is...... Karl?

# %%
wage = 20
print("wage is",end=' ')
print(wage)
print("goodbye")
# Out:
# wage is 20
# goodbye

# %%
wage = 20
print("wage: ",wage)
print("goodbye")
# Out:
# wage:  20
# goodbye

# %%
print("1\n2\n3")
# Out:
# 1
# 2
# 3

# %%
print("123")
print()
print("abc")
# Out:
# 123
#
# abc

# %%
print('Enter name of best friend:',end=' ')
best_friend = input()
print("My best friend is ", best_friend)
# Out:
# Enter name of best friend: My best friend is  Kabir

# %%
my_string = '123'
my_int = int('123')
print(my_string)
print(my_int)
# Out:
# 123
# 123

# %%
print("Enter wage:", end=' ')
wage = int(input())
new_wage = wage + 10
print('New wage:', new_wage)
# Out:
# Enter wage: New wage: 18

# %%
n = int(input())
n = n + 20
print(n,type(n))
# Out:
# 40 <class 'int'>

# %%
print("current salary is", end=' ')
print(45000)
# Out:
# current salary is 45000
