# %%
print('Enter x: ')
x = int(input())

print(x) # Student mistakenly is echoing the input to output to match example
print('x doubled is:', (2 * x))
# Out:
# Enter x:
# 5
# x doubled is: 10

# %%
print('NO PARKING')
print('2:00 - 6:00a.m.')
# Out:
# NO PARKING
# 2:00 - 6:00a.m.

# %%
user_name = input()
print('Hello ', user_name,' and welcome to CS Online!')
# Out:
# Hello  Kabir  and welcome to CS Online!

# %%
first_name = input()
generic_location = input()
whole_number = input()
plural_noun = input()
print(first_name, 'went to', generic_location, 'to buy', whole_number, 'different types of', plural_noun)
# Out:
# Brenda went to Philadelphia to buy 6 different types of bells

# %%
print('Hello world!')
print('How are you?')
print('I am fine')
# Out:
# Hello world!
# How are you?
# I am fine

# %%
user_num = int(input('Enter integer:\n'))
squared = user_num * user_num
cubed = squared * user_num
print('You Entered: ',user_num)
print(user_num,'squared is ',squared)
print('And',user_num,'cubed is',cubed,'!!')
user_new_num = int(input("Enter another integer:"))
addition = user_num + user_new_num
multi = user_num * user_new_num
print(user_num,'+',user_new_num,'is',addition)
print(user_num,'*',user_new_num,'is',multi)
# Out:
# You Entered:  4
# 4 squared is  16
# And 4 cubed is 64 !!
# 4 + 5 is 9
# 4 * 5 is 20

# %%
print("'''")
print("*")
print("***")
print('')
print('')
print("'''")
print("")
print("o o")
print("= =")
print("---")
print("'''")
# Out:
# '''
# *
# ***
#
#
# '''
# /\ /
# o o
# = =
# ---
# '''
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_3792/3996100508.py:7: SyntaxWarning: invalid escape sequence '\ '
#   print("/\ /")

# %%
print("Step 1 complete")
print("Step 2 as well")
print("All steps now complete")
# Out:
# Step 1 complete
# Step 2 as well
# All steps now complete

# %%
user_num = int(input())
x = int(input())
user_num = user_num / x
print(user_num)
user_num = user_num / x
print(user_num)
user_num = user_num / x
print(user_num)
# Out:
# 500.0
# 250.0
# 125.0

# %%
caffeine_mg = float(input())
caffeine_mg = caffeine_mg / 2
print("After 6 hours: ",caffeine_mg,'mg')
caffeine_mg = caffeine_mg / 2
print("After 12 hours: ",caffeine_mg,'mg')
caffeine_mg = caffeine_mg / 4
print("After 24 hours: ",caffeine_mg,'mg')
# Out:
# After 6 hours:  50.0 mg
# After 12 hours:  25.0 mg
# After 24 hours:  6.25 mg

# %%
Age = int(input())
Weight = int(input())
Heart_rate = int(input())
Time = int(input())
Calories = ((Age * 0.2757) + (Weight *  0.03295) + (Heart_rate * 1.0781) - 75.4991) * Time / 8.368
print("Calories : ",Calories,"calories")
# Out:
# Calories :  736.2063814531549 calories

# %%
import math
x = float(input())
y = float(input())
z = float(input())

# %%
user_int = int(input('Enter integer (32 - 126):\n'))
user_float = float(input('Enter float:\n'))
user_char = str(input('Enter character:\n'))
user_str = str(input('Enter string:\n'))
print(user_int,user_float,user_char,user_str,'\n')
print(user_str,user_char,user_float,user_int,'\n')
user_int_to_char = chr(user_int)
print(user_int,'converted to a character is ',user_int_to_char)
# Out:
# 99 3.77 z Howdy
#
# Howdy z 3.77 99
#
# 99 converted to a character is  c

# %%
caffeine_mg = float(input())
caffeine_mg = caffeine_mg / 2
print("After 6 hours: ",caffeine_mg,'mg')
caffeine_mg = caffeine_mg / 2
print("After 12 hours: ",caffeine_mg,'mg')
caffeine_mg = caffeine_mg / 4
print("After 24 hours: ",caffeine_mg,'mg')
# Out:
# After 6 hours:  50.0 mg
# After 12 hours:  25.0 mg
# After 24 hours:  6.25 mg

# %%
current_price = int(input())
last_months_price = int(input())
change = last_months_price - current_price
mortgage = (current_price * 0.051) / 12
print("This house is ",current_price,". The change is -",change,"since last month. The estimated monthly mortgage is $",mortgage)
# Out:
# This house is  200000 . The change is - 10000 since last month. The estimated monthly mortgage is $ 850.0

# %%
favorite_color = input('Enter favorite color:\n')
favorite_flower = input('Enter favorite flower:\n')
favorite_num = input('Enter favorite number:\n') 
first_password = favorite_color + '_' + favorite_flower
second_password = favorite_num + favorite_color + favorite_num
print("You entered:",favorite_color,favorite_flower,favorite_num)
print("First password:",first_password)
print("Second password:",second_password)
print("Number of characters in",first_password,':',len[first_password])
print("Number of characters in",second_password,":",len[second_password_password])
# Out:
# You entered: yellow Daisy 6
# First password: yellow_Daisy
# Second password: 6yellow6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       7 print("First password:",first_password)
#       8 print("Second password:",second_password)
# ----> 9 print("Number of characters in",first_password,':',len[first_password])
#      10 print("Number of characters in",second_password,":",len[second_password_password])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
